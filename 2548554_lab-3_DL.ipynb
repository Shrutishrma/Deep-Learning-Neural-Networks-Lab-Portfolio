# %% [raw]
# Dataset description:  The dataset contains sports footwear sales information including brand, size, base price and discount.
#
# Target variable: Final selling price.
#
# Input features:
#
# 1. Shoe size
#
# 2. Base price
#
# 3. Discount percent

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Loading Dataset

# %%
data = pd.read_csv("global_sports_footwear_sales_2018_2026.csv")
data
# Out:
#         order_id  order_date        brand model_name    category  gender  \
# 0      ORD100000  2021-01-30        ASICS  Model-370     Running  Unisex
# 1      ORD100001  2026-10-05       Reebok  Model-314   Lifestyle     Men
# 2      ORD100002  2023-11-12        ASICS  Model-763   Lifestyle     Men
# 3      ORD100003  2026-08-29       Reebok  Model-905  Basketball   Women
# 4      ORD100004  2019-11-09         Nike  Model-413    Training     Men
# ...          ...         ...          ...        ...         ...     ...
# 29995  ORD129995  2018-05-28         Puma  Model-892         Gym   Women
# 29996  ORD129996  2018-04-28       Adidas  Model-982     Running   Women
# 29997  ORD129997  2026-02-17        ASICS  Model-463  Basketball     Men
# 29998  ORD129998  2024-02-21  New Balance  Model-984     Running  Unisex
# 29999  ORD129999  2020-06-18         Nike  Model-604     Running     Men
#
#        size  color  base_price_usd  discount_percent  final_price_usd  \
# ...

# %% [markdown]
# ### Feature Selection

# %%
data["final_price"] = data["base_price_usd"] * (1 - data["discount_percent"]/100)
X = data[["size", "base_price_usd", "discount_percent"]]
y = data["final_price"]

# %% [markdown]
# ### Train-Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Models
models = {
    "Linear": LinearRegression(),
    "Ridge": Ridge(alpha=1),
    "Lasso": Lasso(alpha=0.1),
    "ElasticNet": ElasticNet(alpha=0.1, l1_ratio=0.5)}

# %%
# Train and compare
for name, model in models.items():
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    mse = mean_squared_error(y_test, preds)

    print("\n", name)
    print("Coefficients:", model.coef_)
    print("MSE:", mse)
# Out:
#  Linear
# Coefficients: [-0.01343843  0.86713323 -1.40095902]
# MSE: 20.907020595093808
#
#  Ridge
# Coefficients: [-0.01343822  0.86713321 -1.40095834]
# MSE: 20.90701800915096
#
#  Lasso
# Coefficients: [-0.          0.86708776 -1.39994153]
# MSE: 20.901469091773805
#
#  ElasticNet
# Coefficients: [-0.          0.86709092 -1.39973769]
# MSE: 20.900773161677204

# %% [markdown]
# ### Feature Removal Check

# %%
print("Features removed by Lasso:", X.columns[model.coef_ == 0])
# Out:
# Features removed by Lasso: Index(['size'], dtype='object')

# %% [raw]
# Lasso regression eliminated the feature size, indicating that shoe size has negligible impact on final price. This demonstrates the feature selection property of L1 regularization.

# %% [raw]
# #Interpretation
#
# Linear regression uses all features, even less useful ones.
# Ridge regression slightly reduces the magnitude of coefficients but keeps all features.
# Lasso regression performs feature selection by eliminating shoe size as it has negligible impact on final price.
# Elastic Net combines both approaches and also removes irrelevant features.
# This shows that regularization helps simplify the model and improve generalization.
